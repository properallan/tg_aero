# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler, MaxAbsScaler
from sklearn.decomposition import IncrementalPCA, PCA

from sklearn.base import BaseEstimator, TransformerMixin


from frog.flow_reconstruction import FlowReconstruction
from frog.normalization import SliceMinMaxScaler, SliceMaxAbsScaler
from frog.transformers import IdentityTransformer, MeanCentering, SliceMeanCentering

import xarray as xr
import numpy as np

from sklearn.metrics import r2_score

import time
from sklearn.pipeline import Pipeline
from sklearn.decomposition import IncrementalPCA
from sklearn.preprocessing import MaxAbsScaler
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel
from sklearn.metrics import r2_score, root_mean_squared_error

from frog.neuralnetwork import NeuralNetwork

from tensorflow.keras.optimizers import Adam

def nrmse(y_true, y_pred, normalization='range'):
    """
    Calcula o Normalized Root Mean Squared Error (NRMSE).

    Parâmetros:
    y_true : array-like
        Valores verdadeiros.
    y_pred : array-like
        Valores previstos pelo modelo.
    normalization : str, opcional (padrão='range')
        Método de normalização. Opções: 'range' ou 'mean'.
    
    Retorna:
    float
        O valor do NRMSE.
    """
    # Garante que os inputs são arrays numpy
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)

    rmse = root_mean_squared_error(y_true, y_pred)
    
    if normalization == 'range':
        denominator = np.max(y_true) - np.min(y_true)
    elif normalization == 'mean':
        denominator = np.mean(y_true)
    else:
        raise ValueError("O método de normalização deve ser 'range' ou 'mean'.")
        
    if denominator == 0:
        # Evita divisão por zero se todos os valores de y_true forem iguais
        return np.inf

    return rmse / denominator

def train_model(data_train, data_test, data_validation=None, n_components_X=10, n_components_y=10, save_file=None):
    X_train, y_train = data_train
    X_test, y_test = data_test
    

    y_rom = Pipeline([
        ('scaler', MaxAbsScaler()), 
        ('reducer', IncrementalPCA(n_components=n_components_y))
    ])
    
    X_rom = Pipeline([
        ('scaler', MaxAbsScaler()), 
        ('reducer', IncrementalPCA(n_components=n_components_X))
    ])

    
    model = FlowReconstruction(
        X_rom=X_rom,
        y_rom=y_rom,
        surrogate=Pipeline([
            ('regressor', NeuralNetwork(
                num_inputs=n_components_X, 
                num_outputs=n_components_y,
                num_layers=10,
                num_neurons=10,
                activation='tanh', 
                optimizer=Adam(learning_rate=0.0001),
                loss='mse'
            ))
        ]),
        surrogate_kwargs={}
    )

    # Início da contagem de tempo
    start_time = time.time()
    from tensorflow.keras.callbacks import CSVLogger

    csv_logger = CSVLogger('../data/nn_training_log.csv')

    model.fit(X=X_train, y=y_train, 
              regressor__epochs= 10_000, 
              regressor__batch_size= 10,
              regressor__validation_data= data_validation,
              regressor__callbacks=[csv_logger])

    # Fim da contagem de tempo
    end_time = time.time()
    elapsed_time = end_time - start_time

    prediction = model.predict(X_test)

    r2 = r2_score(y_test.flatten(), prediction.flatten())
    nrmse_value = nrmse(y_test, prediction, normalization='range')
    eps = 1e-10
    max_relative_error = np.max(np.abs((y_test - prediction) / (y_test + eps)))  # Pequeno valor para evitar divisão por zero
    max_abs_error = np.max(np.abs(y_test - prediction))

    print(f"Training completed")
    print(f"R2 Score: {r2:.6f}")
    print(f"NRMSE: {nrmse_value:.6f}")
    print(f"Max Relative Error: {max_relative_error:.6f}")
    print(f"Max Absolute Error: {max_abs_error:.6f}")
    print(f"Training time: {elapsed_time:.2f} seconds")


    if save_file is not None:
        print(f"Saving model to {save_file}")
        model.save(save_file)

    return model

# %%
# from data_handler import split_dataset_named


# y_data_train, y_data_test, y_data_val = split_dataset_named(
#     xr.open_dataset("../data/SU2_fluid.nc"),
#     dim="phony_dim_1",
#     frac=(0.80, 0.10, 0.10),
#     seed=42,
#     sort=False,
# )

# X_data_train, X_data_test, X_data_val = split_dataset_named(
#     xr.open_dataset("../data/Q1D.nc"),
#     dim="phony_dim_1",
#     frac=(0.80, 0.10, 0.10),
#     seed=42,
#     sort=False
# )

# %%
data_type = 'hdf5'  # 'hdf5' or 'xarray'

ntrain=145
nvalidation = ntrain+18
ntest = nvalidation+18

X_variable=['p.txt', 'T.txt', 'M.txt']
y_variable=['Pressure', 'Temperature', 'Mach', 'Heat_Flux']
if data_type == 'hdf5':
    from data_handler import dataHandler


    bc = dataHandler(
        '../data/Q1D.hdf5', 
        ['p0in', 'T0in'])

    lfd = dataHandler(
        '../data/Q1D.hdf5', 
        X_variable)

    hfd = dataHandler(
        '../data/SU2_fluid.hdf5',
        y_variable)

    
    X_train = lfd.data[:,:ntrain].T
    y_train = hfd.data[:,:ntrain].T
    bc_train = bc.data[:,:ntrain].T

    X_validation = lfd.data[:,ntrain:nvalidation].T
    y_validation = hfd.data[:,ntrain:nvalidation].T
    bc_validation = bc.data[:,ntrain:nvalidation].T

    X_test = lfd.data[:,nvalidation:ntest].T
    y_test = hfd.data[:,nvalidation:ntest].T
    bc_test = bc.data[:,nvalidation:ntest].T

elif data_type == 'xarray':
    from data_handler import dataHandler
    import xarray as xr
    import numpy as np

    bc = dataHandler(
        '../data/Q1D.hdf5', 
        ['p0in', 'T0in'])

    lfd = dataHandler(
        '../data/Q1D.hdf5', 
        X_variable)

    hfd = dataHandler(
        '../data/SU2_fluid.hdf5',
        y_variable)

    lfd_data = xr.open_dataset("../data/Q1D.nc")
    lfd_data = lfd_data[X_variable].to_array().values  # Flatten the first two dimensions
    lfd_data = lfd_data.reshape(-1, lfd_data.shape[-1])

    hfd_data = xr.open_dataset("../data/SU2_fluid.nc")
    data_list = []
    for var in y_variable:
        data = hfd_data[[var]].to_array().values
        data_list.append(data.reshape(-1, data.shape[-1]))
    hfd_data = np.vstack(data_list)

    bc_data = xr.open_dataset("../data/SU2_fluid.nc")
    bc_data = bc_data[['p0in', 'T0in']].to_array().values
    bc_data = bc_data.reshape(-1, bc_data.shape[-1])

    X_train = lfd_data[:,:ntrain].T
    y_train = hfd_data[:,:ntrain].T
    bc_train = bc_data[:,:ntrain].T

    X_validation = lfd_data[:,ntrain:nvalidation].T
    y_validation = hfd_data[:,ntrain:nvalidation].T
    bc_validation = bc_data[:,ntrain:nvalidation].T

    X_test = lfd_data[:,nvalidation:ntest].T
    y_test = hfd_data[:,nvalidation:ntest].T
    bc_test = bc_data[:,nvalidation:ntest].T

elif data_type == 'xarray2':
    from data_handler import split_dataset_named


    y_data_train, y_data_test, y_data_val = split_dataset_named(
        xr.open_dataset("../data/SU2_fluid.nc"),
        dim="phony_dim_1",
        frac=(0.80, 0.10, 0.10),
        seed=42,
        sort=False,
    )

    X_data_train, X_data_test, X_data_val = split_dataset_named(
        xr.open_dataset("../data/Q1D.nc"),
        dim="phony_dim_1",
        frac=(0.80, 0.10, 0.10),
        seed=42,
        sort=False
    )


    def to_array(dataset, variables):
        data_list = []
        for var in variables:
            data = dataset[[var]].to_array().values
            data_list.append(data.reshape(-1, data.shape[-1]))
        return np.vstack(data_list)
    
    X_train = to_array(X_data_train, X_variable).T
    y_train = to_array(y_data_train, y_variable).T
    bc_train = to_array(y_data_train, ['p0in', 'T0in']).T

    X_test = to_array(X_data_test, X_variable).T
    y_test = to_array(y_data_test, y_variable).T
    bc_test = to_array(y_data_train, ['p0in', 'T0in']).T

    X_validation = to_array(X_data_val, X_variable).T
    y_validation = to_array(y_data_val, y_variable).T
    bc_validation = to_array(y_data_train, ['p0in', 'T0in']).T

# %%
model = train_model(
    data_train=(X_train, y_train),  # Não utilizado, mas necessário para a assinatura da função
    data_test=(X_test, y_test),   # Não utilizado, mas necessário para a assinatura da função
    n_components_X=3,
    n_components_y=3,
    save_file="../data/nn_model",
    data_validation=(X_validation, y_validation)
)
# Out:
# Performing ROM fit on X data
# Performing ROM fit on y data
# Performing ROM fit on X validation data
# Performing ROM fit on y validation data
# Performing surrogate model fit
# Epoch 1/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 843.5530 - val_loss: 1111.8296
# Epoch 2/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 841.7877 - val_loss: 1109.7778
# Epoch 3/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 840.0903 - val_loss: 1107.7473
# Epoch 4/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 838.3948 - val_loss: 1105.6835
# Epoch 5/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 836.6592 - val_loss: 1103.5621
# Epoch 6/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 834.8698 - val_loss: 1101.3898
# Epoch 7/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 833.0365 - val_loss: 1099.1884
# Epoch 8/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 831.1794 - val_loss: 1096.9829
# Epoch 9/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 829.3193 - val_loss: 1094.7920
# Epoch 10/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 827.4714 - val_loss: 1092.6257
# Epoch 11/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 825.6433 - val_loss: 1090.4861
# Epoch 12/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 823.8362 - val_loss: 1088.3698
# Epoch 13/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 822.0472 - val_loss: 1086.2708
# Epoch 14/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 820.2713 - val_loss: 1084.1827
# Epoch 15/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 818.5038 - val_loss: 1082.1002
# Epoch 16/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 816.7408 - val_loss: 1080.0201
# Epoch 17/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 814.9798 - val_loss: 1077.9417
# Epoch 18/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 813.2211 - val_loss: 1075.8661
# Epoch 19/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 811.4658 - val_loss: 1073.7961
# Epoch 20/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 809.7166 - val_loss: 1071.7352
# Epoch 21/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 807.9763 - val_loss: 1069.6869
# Epoch 22/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 806.2479 - val_loss: 1067.6548
# Epoch 23/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 804.5347 - val_loss: 1065.6426
# Epoch 24/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 802.8397 - val_loss: 1063.6545
# Epoch 25/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 801.1663 - val_loss: 1061.6940
# Epoch 26/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 799.5175 - val_loss: 1059.7649
# Epoch 27/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 797.8963 - val_loss: 1057.8700
# Epoch 28/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 796.3049 - val_loss: 1056.0117
# Epoch 29/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 794.7451 - val_loss: 1054.1917
# Epoch 30/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 793.2183 - val_loss: 1052.4106
# Epoch 31/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 791.7250 - val_loss: 1050.6693
# Epoch 32/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 790.2651 - val_loss: 1048.9668
# Epoch 33/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 788.8383 - val_loss: 1047.3026
# Epoch 34/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 787.4439 - val_loss: 1045.6761
# Epoch 35/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 786.0814 - val_loss: 1044.0861
# Epoch 36/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 784.7495 - val_loss: 1042.5315
# Epoch 37/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 783.4474 - val_loss: 1041.0112
# Epoch 38/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 782.1743 - val_loss: 1039.5243
# Epoch 39/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 780.9290 - val_loss: 1038.0692
# Epoch 40/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 779.7106 - val_loss: 1036.6451
# Epoch 41/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 778.5182 - val_loss: 1035.2506
# Epoch 42/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 777.3505 - val_loss: 1033.8845
# Epoch 43/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 776.2068 - val_loss: 1032.5458
# Epoch 44/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 775.0858 - val_loss: 1031.2329
# Epoch 45/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 773.9866 - val_loss: 1029.9452
# Epoch 46/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 772.9080 - val_loss: 1028.6809
# Epoch 47/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 771.8494 - val_loss: 1027.4391
# Epoch 48/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 770.8094 - val_loss: 1026.2188
# Epoch 49/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 769.7872 - val_loss: 1025.0187
# Epoch 50/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 768.7820 - val_loss: 1023.8378
# Epoch 51/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 767.7930 - val_loss: 1022.6752
# Epoch 52/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 766.8191 - val_loss: 1021.5300
# Epoch 53/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 765.8596 - val_loss: 1020.4011
# Epoch 54/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 764.9138 - val_loss: 1019.2878
# Epoch 55/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 763.9810 - val_loss: 1018.1895
# Epoch 56/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 763.0607 - val_loss: 1017.1050
# Epoch 57/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 762.1522 - val_loss: 1016.0345
# Epoch 58/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 761.2551 - val_loss: 1014.9768
# Epoch 59/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 760.3689 - val_loss: 1013.9316
# Epoch 60/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 759.4933 - val_loss: 1012.8987
# Epoch 61/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 758.6280 - val_loss: 1011.8778
# Epoch 62/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 757.7727 - val_loss: 1010.8684
# Epoch 63/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 756.9272 - val_loss: 1009.8704
# Epoch 64/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 756.0915 - val_loss: 1008.8835
# Epoch 65/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 755.2651 - val_loss: 1007.9079
# Epoch 66/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 754.4481 - val_loss: 1006.9431
# Epoch 67/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 753.6404 - val_loss: 1005.9891
# Epoch 68/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 752.8420 - val_loss: 1005.0458
# Epoch 69/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 752.0526 - val_loss: 1004.1132
# Epoch 70/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 751.2722 - val_loss: 1003.1911
# Epoch 71/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 750.5008 - val_loss: 1002.2794
# Epoch 72/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 749.7383 - val_loss: 1001.3781
# Epoch 73/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 748.9844 - val_loss: 1000.4870
# Epoch 74/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 748.2393 - val_loss: 999.6059
# Epoch 75/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 747.5028 - val_loss: 998.7348
# Epoch 76/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 746.7747 - val_loss: 997.8736
# Epoch 77/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 746.0549 - val_loss: 997.0219
# Epoch 78/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 745.3433 - val_loss: 996.1799
# Epoch 79/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 744.6398 - val_loss: 995.3472
# Epoch 80/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 743.9442 - val_loss: 994.5237
# Epoch 81/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 743.2563 - val_loss: 993.7092
# Epoch 82/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 742.5763 - val_loss: 992.9036
# Epoch 83/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 741.9037 - val_loss: 992.1066
# Epoch 84/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 741.2382 - val_loss: 991.3181
# Epoch 85/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 740.5801 - val_loss: 990.5378
# Epoch 86/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 739.9289 - val_loss: 989.7659
# Epoch 87/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 739.2846 - val_loss: 989.0015
# Epoch 88/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 738.6470 - val_loss: 988.2451
# Epoch 89/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 738.0160 - val_loss: 987.4962
# Epoch 90/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 737.3913 - val_loss: 986.7546
# Epoch 91/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 736.7729 - val_loss: 986.0205
# Epoch 92/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 736.1605 - val_loss: 985.2932
# Epoch 93/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 735.5541 - val_loss: 984.5727
# Epoch 94/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 734.9534 - val_loss: 983.8589
# Epoch 95/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 734.3583 - val_loss: 983.1516
# Epoch 96/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 733.7688 - val_loss: 982.4506
# Epoch 97/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 733.1846 - val_loss: 981.7559
# Epoch 98/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 732.6055 - val_loss: 981.0668
# Epoch 99/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 732.0316 - val_loss: 980.3839
# Epoch 100/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 731.4625 - val_loss: 979.7067
# Epoch 101/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 730.8983 - val_loss: 979.0349
# Epoch 102/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 730.3387 - val_loss: 978.3685
# Epoch 103/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 729.7837 - val_loss: 977.7075
# Epoch 104/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 729.2331 - val_loss: 977.0515
# Epoch 105/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 728.6869 - val_loss: 976.4004
# Epoch 106/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 728.1448 - val_loss: 975.7543
# Epoch 107/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 727.6068 - val_loss: 975.1129
# Epoch 108/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 727.0728 - val_loss: 974.4761
# Epoch 109/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 726.5427 - val_loss: 973.8438
# Epoch 110/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 726.0164 - val_loss: 973.2157
# Epoch 111/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 725.4937 - val_loss: 972.5920
# Epoch 112/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 724.9747 - val_loss: 971.9724
# Epoch 113/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 724.4591 - val_loss: 971.3568
# Epoch 114/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 723.9470 - val_loss: 970.7451
# Epoch 115/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 723.4380 - val_loss: 970.1374
# Epoch 116/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 722.9324 - val_loss: 969.5332
# Epoch 117/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 722.4299 - val_loss: 968.9327
# Epoch 118/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 721.9304 - val_loss: 968.3358
# Epoch 119/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 721.4339 - val_loss: 967.7423
# Epoch 120/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 720.9404 - val_loss: 967.1521
# Epoch 121/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 720.4497 - val_loss: 966.5652
# Epoch 122/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 719.9618 - val_loss: 965.9817
# Epoch 123/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 719.4764 - val_loss: 965.4011
# Epoch 124/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 718.9939 - val_loss: 964.8237
# Epoch 125/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 718.5138 - val_loss: 964.2491
# Epoch 126/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 718.0363 - val_loss: 963.6775
# Epoch 127/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 717.5612 - val_loss: 963.1086
# Epoch 128/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 717.0884 - val_loss: 962.5427
# Epoch 129/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 716.6180 - val_loss: 961.9792
# Epoch 130/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 716.1498 - val_loss: 961.4185
# Epoch 131/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 715.6839 - val_loss: 960.8602
# Epoch 132/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 715.2202 - val_loss: 960.3047
# Epoch 133/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 714.7585 - val_loss: 959.7514
# Epoch 134/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 714.2990 - val_loss: 959.2005
# Epoch 135/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 713.8414 - val_loss: 958.6521
# Epoch 136/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 713.3858 - val_loss: 958.1058
# Epoch 137/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 712.9322 - val_loss: 957.5618
# Epoch 138/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 712.4803 - val_loss: 957.0200
# Epoch 139/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 712.0304 - val_loss: 956.4803
# Epoch 140/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 711.5823 - val_loss: 955.9427
# Epoch 141/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 711.1359 - val_loss: 955.4070
# Epoch 142/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 710.6912 - val_loss: 954.8735
# Epoch 143/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 710.2482 - val_loss: 954.3420
# Epoch 144/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 709.8069 - val_loss: 953.8121
# Epoch 145/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 709.3672 - val_loss: 953.2843
# Epoch 146/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 708.9291 - val_loss: 952.7582
# Epoch 147/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 708.4924 - val_loss: 952.2341
# Epoch 148/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 708.0574 - val_loss: 951.7116
# Epoch 149/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 707.6237 - val_loss: 951.1907
# Epoch 150/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 707.1916 - val_loss: 950.6716
# Epoch 151/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 706.7608 - val_loss: 950.1543
# Epoch 152/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 706.3314 - val_loss: 949.6384
# Epoch 153/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 705.9034 - val_loss: 949.1241
# Epoch 154/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 705.4767 - val_loss: 948.6111
# Epoch 155/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 705.0518 - val_loss: 948.1008
# Epoch 156/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 704.6291 - val_loss: 947.5896
# Epoch 157/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 704.2090 - val_loss: 947.0827
# Epoch 158/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 703.7839 - val_loss: 946.5753
# Epoch 159/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 703.3629 - val_loss: 946.0703
# Epoch 160/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 702.9431 - val_loss: 945.5660
# Epoch 161/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 702.5248 - val_loss: 945.0636
# Epoch 162/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 702.1075 - val_loss: 944.5621
# Epoch 163/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 701.6914 - val_loss: 944.0621
# Epoch 164/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 701.2759 - val_loss: 943.5632
# Epoch 165/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 700.8613 - val_loss: 943.0657
# Epoch 166/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 700.4468 - val_loss: 942.5692
# Epoch 167/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 700.0317 - val_loss: 942.0741
# Epoch 168/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 699.6127 - val_loss: 941.5797
# Epoch 169/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 699.1792 - val_loss: 941.0855
# Epoch 170/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 698.7697 - val_loss: 940.5966
# Epoch 171/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 698.3656 - val_loss: 940.1048
# Epoch 172/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 697.9425 - val_loss: 939.6160
# Epoch 173/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 697.5321 - val_loss: 939.1267
# Epoch 174/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 697.1263 - val_loss: 938.6400
# Epoch 175/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 696.7214 - val_loss: 938.1528
# Epoch 176/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 696.3184 - val_loss: 937.6680
# Epoch 177/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 695.9142 - val_loss: 937.1829
# Epoch 178/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 695.5123 - val_loss: 936.6999
# Epoch 179/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 695.1104 - val_loss: 936.2169
# Epoch 180/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 694.7104 - val_loss: 935.7357
# Epoch 181/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 694.3107 - val_loss: 935.2548
# Epoch 182/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 693.9126 - val_loss: 934.7755
# Epoch 183/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 693.5147 - val_loss: 934.2964
# Epoch 184/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 693.1184 - val_loss: 933.8188
# Epoch 185/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 692.7222 - val_loss: 933.3416
# Epoch 186/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 692.3276 - val_loss: 932.8660
# Epoch 187/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 691.9330 - val_loss: 932.3905
# Epoch 188/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 691.5398 - val_loss: 931.9167
# Epoch 189/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 691.1466 - val_loss: 931.4427
# Epoch 190/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 690.7550 - val_loss: 930.9705
# Epoch 191/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 690.3632 - val_loss: 930.4985
# Epoch 192/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 689.9729 - val_loss: 930.0278
# Epoch 193/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 689.5824 - val_loss: 929.5573
# Epoch 194/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 689.1935 - val_loss: 929.0883
# Epoch 195/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 688.8043 - val_loss: 928.6194
# Epoch 196/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 688.4168 - val_loss: 928.1520
# Epoch 197/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 688.0289 - val_loss: 927.6844
# Epoch 198/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 687.6428 - val_loss: 927.2186
# Epoch 199/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 687.2563 - val_loss: 926.7528
# Epoch 200/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 686.8714 - val_loss: 926.2882
# Epoch 201/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 686.4861 - val_loss: 925.8238
# Epoch 202/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 686.1025 - val_loss: 925.3607
# Epoch 203/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 685.7184 - val_loss: 924.8976
# Epoch 204/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 685.3360 - val_loss: 924.4359
# Epoch 205/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 684.9532 - val_loss: 923.9742
# Epoch 206/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 684.5718 - val_loss: 923.5139
# Epoch 207/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 684.1902 - val_loss: 923.0534
# Epoch 208/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 683.8101 - val_loss: 922.5944
# Epoch 209/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 683.4296 - val_loss: 922.1353
# Epoch 210/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 683.0506 - val_loss: 921.6775
# Epoch 211/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 682.6711 - val_loss: 921.2197
# Epoch 212/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 682.2932 - val_loss: 920.7632
# Epoch 213/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 681.9149 - val_loss: 920.3068
# Epoch 214/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 681.5381 - val_loss: 919.8513
# Epoch 215/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 681.1608 - val_loss: 919.3961
# Epoch 216/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 680.7850 - val_loss: 918.9418
# Epoch 217/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 680.4087 - val_loss: 918.4876
# Epoch 218/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 680.0340 - val_loss: 918.0347
# Epoch 219/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 679.6586 - val_loss: 917.5818
# Epoch 220/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 679.2849 - val_loss: 917.1298
# Epoch 221/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 678.9105 - val_loss: 916.6780
# Epoch 222/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 678.5378 - val_loss: 916.2272
# Epoch 223/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 678.1644 - val_loss: 915.7764
# Epoch 224/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 677.7927 - val_loss: 915.3266
# Epoch 225/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 677.4202 - val_loss: 914.8770
# Epoch 226/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 677.0494 - val_loss: 914.4283
# Epoch 227/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 676.6778 - val_loss: 913.9797
# Epoch 228/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 676.3080 - val_loss: 913.5321
# Epoch 229/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 675.9373 - val_loss: 913.0844
# Epoch 230/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 675.5683 - val_loss: 912.6378
# Epoch 231/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 675.1985 - val_loss: 912.1912
# Epoch 232/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 674.8304 - val_loss: 911.7457
# Epoch 233/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 674.4615 - val_loss: 911.3000
# Epoch 234/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 674.0942 - val_loss: 910.8552
# Epoch 235/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 673.7262 - val_loss: 910.4107
# Epoch 236/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 673.3597 - val_loss: 909.9669
# Epoch 237/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 672.9925 - val_loss: 909.5232
# Epoch 238/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 672.6270 - val_loss: 909.0804
# Epoch 239/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 672.2604 - val_loss: 908.6376
# Epoch 240/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 671.8958 - val_loss: 908.1957
# Epoch 241/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 671.5300 - val_loss: 907.7539
# Epoch 242/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 671.1661 - val_loss: 907.3129
# Epoch 243/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 670.8012 - val_loss: 906.8719
# Epoch 244/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 670.4381 - val_loss: 906.4319
# Epoch 245/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 670.0739 - val_loss: 905.9916
# Epoch 246/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 669.7116 - val_loss: 905.5524
# Epoch 247/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 669.3481 - val_loss: 905.1131
# Epoch 248/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 668.9866 - val_loss: 904.6747
# Epoch 249/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 668.6238 - val_loss: 904.2363
# Epoch 250/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 668.2630 - val_loss: 903.7986
# Epoch 251/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 667.9011 - val_loss: 903.3611
# Epoch 252/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 667.5410 - val_loss: 902.9243
# Epoch 253/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 667.1797 - val_loss: 902.4875
# Epoch 254/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 666.8203 - val_loss: 902.0515
# Epoch 255/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 666.4597 - val_loss: 901.6155
# Epoch 256/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 666.1011 - val_loss: 901.1802
# Epoch 257/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 665.7412 - val_loss: 900.7450
# Epoch 258/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 665.3832 - val_loss: 900.3106
# Epoch 259/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 665.0240 - val_loss: 899.8762
# Epoch 260/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 664.6667 - val_loss: 899.4424
# Epoch 261/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 664.3082 - val_loss: 899.0088
# Epoch 262/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 663.9517 - val_loss: 898.5759
# Epoch 263/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 663.5937 - val_loss: 898.1428
# Epoch 264/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 663.2378 - val_loss: 897.7107
# Epoch 265/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 662.8804 - val_loss: 897.2784
# Epoch 266/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 662.5252 - val_loss: 896.8469
# Epoch 267/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 662.1685 - val_loss: 896.4155
# Epoch 268/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 661.8139 - val_loss: 895.9846
# Epoch 269/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 661.4579 - val_loss: 895.5539
# Epoch 270/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 661.1039 - val_loss: 895.1237
# Epoch 271/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 660.7485 - val_loss: 894.6937
# Epoch 272/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 660.3951 - val_loss: 894.2642
# Epoch 273/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 660.0404 - val_loss: 893.8348
# Epoch 274/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 659.6877 - val_loss: 893.4061
# Epoch 275/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 659.3334 - val_loss: 892.9773
# Epoch 276/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 658.9813 - val_loss: 892.5493
# Epoch 277/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 658.6277 - val_loss: 892.1211
# Epoch 278/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 658.2762 - val_loss: 891.6938
# Epoch 279/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 657.9231 - val_loss: 891.2664
# Epoch 280/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 657.5721 - val_loss: 890.8395
# Epoch 281/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 657.2197 - val_loss: 890.4128
# Epoch 282/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 656.8693 - val_loss: 889.9866
# Epoch 283/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 656.5175 - val_loss: 889.5605
# Epoch 284/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 656.1677 - val_loss: 889.1350
# Epoch 285/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 655.8163 - val_loss: 888.7094
# Epoch 286/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 655.4671 - val_loss: 888.2846
# Epoch 287/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 655.1163 - val_loss: 887.8597
# Epoch 288/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 654.7676 - val_loss: 887.4354
# Epoch 289/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 654.4174 - val_loss: 887.0110
# Epoch 290/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 654.0693 - val_loss: 886.5875
# Epoch 291/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 653.7195 - val_loss: 886.1638
# Epoch 292/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 653.3721 - val_loss: 885.7407
# Epoch 293/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 653.0229 - val_loss: 885.3176
# Epoch 294/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 652.6758 - val_loss: 884.8951
# Epoch 295/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 652.3272 - val_loss: 884.4725
# Epoch 296/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 651.9808 - val_loss: 884.0506
# Epoch 297/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 651.6325 - val_loss: 883.6287
# Epoch 298/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 651.2867 - val_loss: 883.2074
# Epoch 299/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 650.9390 - val_loss: 882.7861
# Epoch 300/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 650.5936 - val_loss: 882.3652
# Epoch 301/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 650.2464 - val_loss: 881.9445
# Epoch 302/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 649.9016 - val_loss: 881.5242
# Epoch 303/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 649.5549 - val_loss: 881.1041
# Epoch 304/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 649.2105 - val_loss: 880.6843
# Epoch 305/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 648.8644 - val_loss: 880.2646
# Epoch 306/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 648.5205 - val_loss: 879.8455
# Epoch 307/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 648.1747 - val_loss: 879.4265
# Epoch 308/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 647.8315 - val_loss: 879.0078
# Epoch 309/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 647.4862 - val_loss: 878.5892
# Epoch 310/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 647.1434 - val_loss: 878.1712
# Epoch 311/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 646.7987 - val_loss: 877.7532
# Epoch 312/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 646.4563 - val_loss: 877.3356
# Epoch 313/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 646.1121 - val_loss: 876.9181
# Epoch 314/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 645.7702 - val_loss: 876.5011
# Epoch 315/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 645.4264 - val_loss: 876.0841
# Epoch 316/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 645.0850 - val_loss: 875.6676
# Epoch 317/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 644.7417 - val_loss: 875.2510
# Epoch 318/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 644.4007 - val_loss: 874.8351
# Epoch 319/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 644.0579 - val_loss: 874.4192
# Epoch 320/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 643.7175 - val_loss: 874.0036
# Epoch 321/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 643.3750 - val_loss: 873.5882
# Epoch 322/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 643.0350 - val_loss: 873.1732
# Epoch 323/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 642.6931 - val_loss: 872.7582
# Epoch 324/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 642.3536 - val_loss: 872.3438
# Epoch 325/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 642.0120 - val_loss: 871.9293
# Epoch 326/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 641.6730 - val_loss: 871.5153
# Epoch 327/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 641.3319 - val_loss: 871.1013
# Epoch 328/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 640.9933 - val_loss: 870.6878
# Epoch 329/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 640.6527 - val_loss: 870.2744
# Epoch 330/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 640.3146 - val_loss: 869.8613
# Epoch 331/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 639.9744 - val_loss: 869.4484
# Epoch 332/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 639.6367 - val_loss: 869.0358
# Epoch 333/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 639.2969 - val_loss: 868.6233
# Epoch 334/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 638.9596 - val_loss: 868.2111
# Epoch 335/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 638.6202 - val_loss: 867.7991
# Epoch 336/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 638.2834 - val_loss: 867.3875
# Epoch 337/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 637.9445 - val_loss: 866.9758
# Epoch 338/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 637.6081 - val_loss: 866.5647
# Epoch 339/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 637.2696 - val_loss: 866.1536
# Epoch 340/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 636.9337 - val_loss: 865.7429
# Epoch 341/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 636.5956 - val_loss: 865.3323
# Epoch 342/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 636.2601 - val_loss: 864.9221
# Epoch 343/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 635.9224 - val_loss: 864.5118
# Epoch 344/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 635.5873 - val_loss: 864.1021
# Epoch 345/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 635.2501 - val_loss: 863.6924
# Epoch 346/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 634.9153 - val_loss: 863.2829
# Epoch 347/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 634.5786 - val_loss: 862.8737
# Epoch 348/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 634.2443 - val_loss: 862.4647
# Epoch 349/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 633.9078 - val_loss: 862.0559
# Epoch 350/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 633.5740 - val_loss: 861.6475
# Epoch 351/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 633.2380 - val_loss: 861.2390
# Epoch 352/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 632.9045 - val_loss: 860.8311
# Epoch 353/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 632.5689 - val_loss: 860.4232
# Epoch 354/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 632.2359 - val_loss: 860.0156
# Epoch 355/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 631.9006 - val_loss: 859.6080
# Epoch 356/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 631.5680 - val_loss: 859.2009
# Epoch 357/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 631.2332 - val_loss: 858.7937
# Epoch 358/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 630.9009 - val_loss: 858.3870
# Epoch 359/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 630.5665 - val_loss: 857.9803
# Epoch 360/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 630.2347 - val_loss: 857.5740
# Epoch 361/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 629.9007 - val_loss: 857.1678
# Epoch 362/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 629.5692 - val_loss: 856.7620
# Epoch 363/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 629.2356 - val_loss: 856.3561
# Epoch 364/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 628.9045 - val_loss: 855.9507
# Epoch 365/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 628.5712 - val_loss: 855.5452
# Epoch 366/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 628.2406 - val_loss: 855.1403
# Epoch 367/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 627.9077 - val_loss: 854.7352
# Epoch 368/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 627.5775 - val_loss: 854.3307
# Epoch 369/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 627.2450 - val_loss: 853.9261
# Epoch 370/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 626.9151 - val_loss: 853.5219
# Epoch 371/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 626.5830 - val_loss: 853.1177
# Epoch 372/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 626.2535 - val_loss: 852.7140
# Epoch 373/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 625.9218 - val_loss: 852.3102
# Epoch 374/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 625.5927 - val_loss: 851.9068
# Epoch 375/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 625.2613 - val_loss: 851.5035
# Epoch 376/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 624.9326 - val_loss: 851.1005
# Epoch 377/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 624.6016 - val_loss: 850.6975
# Epoch 378/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 624.2733 - val_loss: 850.2949
# Epoch 379/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 623.9426 - val_loss: 849.8924
# Epoch 380/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 623.6146 - val_loss: 849.4901
# Epoch 381/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 623.2844 - val_loss: 849.0880
# Epoch 382/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 622.9568 - val_loss: 848.6862
# Epoch 383/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 622.6268 - val_loss: 848.2845
# Epoch 384/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 622.2996 - val_loss: 847.8831
# Epoch 385/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 621.9702 - val_loss: 847.4818
# Epoch 386/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 621.6432 - val_loss: 847.0808
# Epoch 387/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 621.3141 - val_loss: 846.6797
# Epoch 388/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 620.9875 - val_loss: 846.2791
# Epoch 389/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 620.6588 - val_loss: 845.8786
# Epoch 390/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 620.3327 - val_loss: 845.4784
# Epoch 391/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 620.0043 - val_loss: 845.0782
# Epoch 392/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 619.6785 - val_loss: 844.6784
# Epoch 393/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 619.3504 - val_loss: 844.2786
# Epoch 394/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 619.0251 - val_loss: 843.8792
# Epoch 395/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 618.6974 - val_loss: 843.4797
# Epoch 396/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 618.3723 - val_loss: 843.0807
# Epoch 397/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 618.0450 - val_loss: 842.6816
# Epoch 398/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 617.7202 - val_loss: 842.2830
# Epoch 399/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 617.3933 - val_loss: 841.8843
# Epoch 400/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 617.0689 - val_loss: 841.4860
# Epoch 401/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 616.7423 - val_loss: 841.0877
# Epoch 402/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 616.4183 - val_loss: 840.6899
# Epoch 403/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 616.0920 - val_loss: 840.2919
# Epoch 404/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 615.7684 - val_loss: 839.8943
# Epoch 405/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 615.4425 - val_loss: 839.4968
# Epoch 406/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 615.1191 - val_loss: 839.0997
# Epoch 407/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 614.7936 - val_loss: 838.7024
# Epoch 408/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 614.4707 - val_loss: 838.3057
# Epoch 409/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 614.1454 - val_loss: 837.9089
# Epoch 410/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 613.8229 - val_loss: 837.5124
# Epoch 411/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 613.4980 - val_loss: 837.1160
# Epoch 412/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 613.1757 - val_loss: 836.7200
# Epoch 413/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 612.8513 - val_loss: 836.3239
# Epoch 414/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 612.5294 - val_loss: 835.9283
# Epoch 415/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 612.2051 - val_loss: 835.5325
# Epoch 416/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 611.8836 - val_loss: 835.1371
# Epoch 417/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 611.5598 - val_loss: 834.7419
# Epoch 418/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 611.2385 - val_loss: 834.3469
# Epoch 419/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 610.9150 - val_loss: 833.9519
# Epoch 420/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 610.5941 - val_loss: 833.5573
# Epoch 421/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 610.2711 - val_loss: 833.1627
# Epoch 422/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 609.9504 - val_loss: 832.7684
# Epoch 423/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 609.6276 - val_loss: 832.3741
# Epoch 424/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 609.3074 - val_loss: 831.9802
# Epoch 425/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 608.9849 - val_loss: 831.5863
# Epoch 426/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 608.6651 - val_loss: 831.1929
# Epoch 427/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 608.3430 - val_loss: 830.7994
# Epoch 428/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 608.0234 - val_loss: 830.4061
# Epoch 429/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 607.7016 - val_loss: 830.0131
# Epoch 430/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 607.3824 - val_loss: 829.6202
# Epoch 431/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 607.0610 - val_loss: 829.2274
# Epoch 432/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 606.7421 - val_loss: 828.8350
# Epoch 433/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 606.4211 - val_loss: 828.4425
# Epoch 434/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 606.1025 - val_loss: 828.0504
# Epoch 435/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 605.7817 - val_loss: 827.6582
# Epoch 436/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 605.4634 - val_loss: 827.2665
# Epoch 437/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 605.1431 - val_loss: 826.8747
# Epoch 438/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 604.8251 - val_loss: 826.4833
# Epoch 439/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 604.5050 - val_loss: 826.0919
# Epoch 440/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 604.1875 - val_loss: 825.7009
# Epoch 441/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 603.8677 - val_loss: 825.3098
# Epoch 442/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 603.5505 - val_loss: 824.9191
# Epoch 443/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 603.2311 - val_loss: 824.5284
# Epoch 444/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 602.9141 - val_loss: 824.1379
# Epoch 445/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 602.5951 - val_loss: 823.7477
# Epoch 446/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 602.2784 - val_loss: 823.3577
# Epoch 447/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 601.9597 - val_loss: 822.9677
# Epoch 448/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 601.6434 - val_loss: 822.5779
# Epoch 449/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 601.3250 - val_loss: 822.1882
# Epoch 450/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 601.0090 - val_loss: 821.7990
# Epoch 451/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 600.6909 - val_loss: 821.4096
# Epoch 452/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 600.3752 - val_loss: 821.0206
# Epoch 453/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 600.0575 - val_loss: 820.6316
# Epoch 454/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 599.7422 - val_loss: 820.2429
# Epoch 455/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 599.4247 - val_loss: 819.8542
# Epoch 456/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 599.1097 - val_loss: 819.4661
# Epoch 457/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 598.7926 - val_loss: 819.0776
# Epoch 458/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 598.4779 - val_loss: 818.6898
# Epoch 459/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 598.1612 - val_loss: 818.3018
# Epoch 460/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 597.8468 - val_loss: 817.9141
# Epoch 461/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 597.5304 - val_loss: 817.5265
# Epoch 462/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 597.2163 - val_loss: 817.1393
# Epoch 463/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 596.9002 - val_loss: 816.7520
# Epoch 464/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 596.5864 - val_loss: 816.3650
# Epoch 465/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 596.2706 - val_loss: 815.9780
# Epoch 466/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 595.9572 - val_loss: 815.5914
# Epoch 467/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 595.6417 - val_loss: 815.2048
# Epoch 468/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 595.3286 - val_loss: 814.8185
# Epoch 469/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 595.0134 - val_loss: 814.4322
# Epoch 470/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 594.7007 - val_loss: 814.0462
# Epoch 471/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 594.3858 - val_loss: 813.6603
# Epoch 472/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 594.0733 - val_loss: 813.2747
# Epoch 473/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 593.7589 - val_loss: 812.8891
# Epoch 474/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 593.4467 - val_loss: 812.5037
# Epoch 475/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 593.1324 - val_loss: 812.1185
# Epoch 476/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 592.8206 - val_loss: 811.7336
# Epoch 477/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 592.5067 - val_loss: 811.3486
# Epoch 478/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 592.1952 - val_loss: 810.9640
# Epoch 479/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 591.8817 - val_loss: 810.5794
# Epoch 480/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 591.5704 - val_loss: 810.1951
# Epoch 481/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 591.2572 - val_loss: 809.8108
# Epoch 482/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 590.9462 - val_loss: 809.4268
# Epoch 483/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 590.6333 - val_loss: 809.0427
# Epoch 484/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 590.3226 - val_loss: 808.6592
# Epoch 485/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 590.0101 - val_loss: 808.2756
# Epoch 486/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 589.6998 - val_loss: 807.8923
# Epoch 487/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 589.3875 - val_loss: 807.5090
# Epoch 488/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 589.0775 - val_loss: 807.1259
# Epoch 489/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 588.7656 - val_loss: 806.7430
# Epoch 490/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 588.4558 - val_loss: 806.3603
# Epoch 491/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 588.1442 - val_loss: 805.9777
# Epoch 492/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 587.8348 - val_loss: 805.5953
# Epoch 493/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 587.5234 - val_loss: 805.2131
# Epoch 494/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 587.2144 - val_loss: 804.8309
# Epoch 495/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 586.9034 - val_loss: 804.4490
# Epoch 496/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 586.5946 - val_loss: 804.0673
# Epoch 497/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 586.2839 - val_loss: 803.6855
# Epoch 498/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 585.9754 - val_loss: 803.3042
# Epoch 499/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 585.6650 - val_loss: 802.9230
# Epoch 500/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 585.3569 - val_loss: 802.5419
# Epoch 501/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 585.0468 - val_loss: 802.1608
# Epoch 502/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 584.7389 - val_loss: 801.7801
# Epoch 503/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 584.4292 - val_loss: 801.3995
# Epoch 504/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 584.1216 - val_loss: 801.0191
# Epoch 505/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 583.8121 - val_loss: 800.6387
# Epoch 506/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 583.5048 - val_loss: 800.2586
# Epoch 507/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 583.1957 - val_loss: 799.8785
# Epoch 508/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 582.8888 - val_loss: 799.4988
# Epoch 509/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 582.5800 - val_loss: 799.1191
# Epoch 510/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 582.2733 - val_loss: 798.7396
# Epoch 511/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 581.9648 - val_loss: 798.3602
# Epoch 512/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 581.6584 - val_loss: 797.9811
# Epoch 513/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 581.3503 - val_loss: 797.6020
# Epoch 514/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 581.0442 - val_loss: 797.2233
# Epoch 515/10000
# ...
# Epoch 9830/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0076
# Epoch 9831/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - val_loss: 0.0083
# Epoch 9832/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0055 - val_loss: 0.0093
# Epoch 9833/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - val_loss: 0.0107
# Epoch 9834/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - val_loss: 0.0128
# Epoch 9835/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - val_loss: 0.0160
# Epoch 9836/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - val_loss: 0.0209
# Epoch 9837/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0127 - val_loss: 0.0287
# Epoch 9838/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0408
# Epoch 9839/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0248 - val_loss: 0.0577
# Epoch 9840/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0345 - val_loss: 0.0774
# Epoch 9841/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0445 - val_loss: 0.0899
# Epoch 9842/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0492 - val_loss: 0.0824
# Epoch 9843/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0435 - val_loss: 0.0556
# Epoch 9844/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0294 - val_loss: 0.0291
# Epoch 9845/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - val_loss: 0.0145
# Epoch 9846/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 9847/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - val_loss: 0.0073
# Epoch 9848/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - val_loss: 0.0069
# Epoch 9849/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0068
# Epoch 9850/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0068
# Epoch 9851/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0069
# Epoch 9852/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0071
# Epoch 9853/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0075
# Epoch 9854/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - val_loss: 0.0081
# Epoch 9855/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - val_loss: 0.0089
# Epoch 9856/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - val_loss: 0.0102
# Epoch 9857/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - val_loss: 0.0120
# Epoch 9858/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - val_loss: 0.0148
# Epoch 9859/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0090 - val_loss: 0.0193
# Epoch 9860/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0118 - val_loss: 0.0265
# Epoch 9861/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163 - val_loss: 0.0380
# Epoch 9862/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0234 - val_loss: 0.0553
# Epoch 9863/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0336 - val_loss: 0.0770
# Epoch 9864/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0451 - val_loss: 0.0948
# Epoch 9865/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - val_loss: 0.0917
# Epoch 9866/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0483 - val_loss: 0.0641
# Epoch 9867/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0336 - val_loss: 0.0328
# Epoch 9868/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - val_loss: 0.0151
# Epoch 9869/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - val_loss: 0.0087
# Epoch 9870/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - val_loss: 0.0071
# Epoch 9871/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - val_loss: 0.0068
# Epoch 9872/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0067
# Epoch 9873/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0067
# Epoch 9874/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0068
# Epoch 9875/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0070
# Epoch 9876/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0074
# Epoch 9877/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0080
# Epoch 9878/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - val_loss: 0.0089
# Epoch 9879/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - val_loss: 0.0102
# Epoch 9880/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - val_loss: 0.0121
# Epoch 9881/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - val_loss: 0.0150
# Epoch 9882/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0090 - val_loss: 0.0194
# Epoch 9883/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0116 - val_loss: 0.0265
# Epoch 9884/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160 - val_loss: 0.0375
# Epoch 9885/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0227 - val_loss: 0.0537
# Epoch 9886/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0322 - val_loss: 0.0738
# Epoch 9887/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0428 - val_loss: 0.0898
# Epoch 9888/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0495 - val_loss: 0.0875
# Epoch 9889/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0462 - val_loss: 0.0629
# Epoch 9890/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0329 - val_loss: 0.0339
# Epoch 9891/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - val_loss: 0.0163
# Epoch 9892/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0097 - val_loss: 0.0094
# Epoch 9893/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - val_loss: 0.0073
# Epoch 9894/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - val_loss: 0.0068
# Epoch 9895/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0067
# Epoch 9896/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0067
# Epoch 9897/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0068
# Epoch 9898/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0070
# Epoch 9899/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0074
# Epoch 9900/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0080
# Epoch 9901/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - val_loss: 0.0088
# Epoch 9902/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - val_loss: 0.0100
# Epoch 9903/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - val_loss: 0.0118
# Epoch 9904/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - val_loss: 0.0146
# Epoch 9905/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0088 - val_loss: 0.0190
# Epoch 9906/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114 - val_loss: 0.0260
# Epoch 9907/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0157 - val_loss: 0.0370
# Epoch 9908/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0225 - val_loss: 0.0536
# Epoch 9909/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0323 - val_loss: 0.0747
# Epoch 9910/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0435 - val_loss: 0.0924
# Epoch 9911/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0510 - val_loss: 0.0908
# Epoch 9912/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0478 - val_loss: 0.0650
# Epoch 9913/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0339 - val_loss: 0.0342
# Epoch 9914/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - val_loss: 0.0159
# Epoch 9915/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0095 - val_loss: 0.0090
# Epoch 9916/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - val_loss: 0.0071
# Epoch 9917/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 9918/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 9919/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 9920/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0067
# Epoch 9921/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0070
# Epoch 9922/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0074
# Epoch 9923/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0080
# Epoch 9924/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - val_loss: 0.0089
# Epoch 9925/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - val_loss: 0.0102
# Epoch 9926/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - val_loss: 0.0121
# Epoch 9927/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - val_loss: 0.0150
# Epoch 9928/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0089 - val_loss: 0.0196
# Epoch 9929/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0116 - val_loss: 0.0268
# Epoch 9930/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160 - val_loss: 0.0381
# Epoch 9931/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0230 - val_loss: 0.0547
# Epoch 9932/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0326 - val_loss: 0.0751
# Epoch 9933/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0433 - val_loss: 0.0907
# Epoch 9934/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0497 - val_loss: 0.0868
# Epoch 9935/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0455 - val_loss: 0.0609
# Epoch 9936/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0318 - val_loss: 0.0321
# Epoch 9937/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0154
# Epoch 9938/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0092 - val_loss: 0.0090
# Epoch 9939/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - val_loss: 0.0071
# Epoch 9940/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0067
# Epoch 9941/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 9942/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 9943/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0067
# Epoch 9944/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0070
# Epoch 9945/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0074
# Epoch 9946/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0081
# Epoch 9947/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - val_loss: 0.0090
# Epoch 9948/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - val_loss: 0.0103
# Epoch 9949/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - val_loss: 0.0123
# Epoch 9950/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - val_loss: 0.0154
# Epoch 9951/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0091 - val_loss: 0.0203
# Epoch 9952/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0120 - val_loss: 0.0280
# Epoch 9953/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0401
# Epoch 9954/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - val_loss: 0.0577
# Epoch 9955/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0343 - val_loss: 0.0786
# Epoch 9956/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0451 - val_loss: 0.0929
# Epoch 9957/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0504 - val_loss: 0.0853
# Epoch 9958/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0445 - val_loss: 0.0567
# Epoch 9959/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0296 - val_loss: 0.0286
# Epoch 9960/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0157 - val_loss: 0.0137
# Epoch 9961/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 9962/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - val_loss: 0.0069
# Epoch 9963/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 9964/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0065
# Epoch 9965/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0066
# Epoch 9966/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0067
# Epoch 9967/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0070
# Epoch 9968/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0075
# Epoch 9969/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0082
# Epoch 9970/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - val_loss: 0.0093
# Epoch 9971/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - val_loss: 0.0107
# Epoch 9972/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - val_loss: 0.0130
# Epoch 9973/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0076 - val_loss: 0.0164
# Epoch 9974/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0096 - val_loss: 0.0218
# Epoch 9975/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0128 - val_loss: 0.0304
# Epoch 9976/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - val_loss: 0.0436
# Epoch 9977/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0260 - val_loss: 0.0621
# Epoch 9978/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0365 - val_loss: 0.0821
# Epoch 9979/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0464 - val_loss: 0.0920
# Epoch 9980/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0493 - val_loss: 0.0786
# Epoch 9981/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0407 - val_loss: 0.0488
# Epoch 9982/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0256 - val_loss: 0.0240
# Epoch 9983/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0134 - val_loss: 0.0120
# Epoch 9984/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 9985/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - val_loss: 0.0068
# Epoch 9986/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - val_loss: 0.0065
# Epoch 9987/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0065
# Epoch 9988/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0066
# Epoch 9989/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - val_loss: 0.0068
# Epoch 9990/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - val_loss: 0.0071
# Epoch 9991/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - val_loss: 0.0077
# Epoch 9992/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - val_loss: 0.0085
# Epoch 9993/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - val_loss: 0.0096
# Epoch 9994/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - val_loss: 0.0113
# Epoch 9995/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - val_loss: 0.0138
# Epoch 9996/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081 - val_loss: 0.0178
# Epoch 9997/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0104 - val_loss: 0.0240
# Epoch 9998/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0141 - val_loss: 0.0339
# Epoch 9999/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - val_loss: 0.0488
# Epoch 10000/10000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0291 - val_loss: 0.0687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training completed
# R2 Score: 1.000000
# NRMSE: 0.000002
# Max Relative Error: 0.059696
# Max Absolute Error: 13735.616811
# Training time: 317.33 seconds
# Saving model to ../data/nn_model
# Saved model to: ../data/nn_model

# %%
# lfd

# X_train = X_data_train[X_variable].to_array().values
# y_train = y_data_train[y_variable].to_array().values

# X_train = X_train.reshape(-1, X_train.shape[-1]).T
# y_train = y_train.reshape(-1, y_train.shape[-1]).T

# X_test = X_data_test[X_variable].to_array().values
# y_test = y_data_test[y_variable].to_array().values

# y_test = y_test.reshape(-1, y_test.shape[-1]).T
# X_test = X_test.reshape(-1, X_test.shape[-1]).T

# model = train_model(
#     data_train=(X_train, y_train),  # Não utilizado, mas necessário para a assinatura da função
#     data_test=(X_test, y_test),   # Não utilizado, mas necessário para a assinatura da função
#     n_components_X=10,
#     n_components_y=10,
#     save_file="../data/gp_model"
# )

# %%
# X_variable=['M.txt', 'T.txt', 'p.txt']
# y_variable=['Heat_Flux']

# X_train = X_data_train[X_variable].to_array().values
# y_train = y_data_train[y_variable].to_array().values

# X_train = X_train.reshape(-1, X_train.shape[-1]).T
# y_train = y_train.reshape(-1, y_train.shape[-1]).T

# X_test = X_data_test[X_variable].to_array().values
# y_test = y_data_test[y_variable].to_array().values

# y_test = y_test.reshape(-1, y_test.shape[-1]).T
# X_test = X_test.reshape(-1, X_test.shape[-1]).T

# model = train_model(
#     data_train=(X_train, y_train),  # Não utilizado, mas necessário para a assinatura da função
#     data_test=(X_test, y_test),   # Não utilizado, mas necessário para a assinatura da função
#     n_components_X=10,
#     n_components_y=10,
#     save_file="../data/gp_model"
# )

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
plt.figure(figsize=(7, 3))
# exemplo: fig, ax = plt.subplots()
ax = plt.gca()  # pega o eixo atual
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

lf_energy = np.cumsum(model.X_rom.named_steps['reducer'].explained_variance_ratio_)*100
x = np.arange(1, len(lf_energy)+1)
ax.plot(x,lf_energy, 
    ls='--', marker='^', label='Low Fidelity Snapshots', color='k')
hf_energy = np.cumsum(model.y_rom.named_steps['reducer'].explained_variance_ratio_)*100

ax.plot(x, hf_energy,
    ls='--', marker='x', label='High Fidelity Snapshots', color='k')
ax.set_xlabel(r"Number of Principal Components")
ax.set_ylabel(r"Explained \\ Variance Ratio (\%)")
ax.set_xticks(x)
ax.legend()
ax.figure.tight_layout()
ax.figure.savefig("../latex_src/Figuras/POD_energy.pdf")

# %%
prediction = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
plt.figure(figsize=(6,6))

# Plot prediction
plt.plot(prediction[0, hfd.indexes['Heat_Flux']][3:-2]/1e6, label=r'Prediction', color='tab:blue', linewidth=2)

# Plot ground truth
plt.plot(y_test[0, hfd.indexes['Heat_Flux']][3:-2]/1e6, label=r'Ground Truth', color='tab:orange', linewidth=2, linestyle='--')

# Title and labels with LaTeX
plt.title(r'Comparison of Heat Flux: Prediction vs Ground Truth', fontsize=16, fontweight='bold')
plt.xlabel(r'Point Index', fontsize=14)
plt.ylabel(r'Heat Flux [$\mathrm{MW/m^2}$]', fontsize=14)

# Grid and style
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
def plot_ground_truth(mesh, vmin, vmax, sargs):
    import pyvista as pv
    plotter = pv.Plotter(window_size=(800,600))
    plotter.add_mesh(mesh, scalars='Ground-Truth', cmap='plasma', clim=(vmin, vmax), scalar_bar_args=sargs)
    plotter.add_mesh(mesh.contour(), color="black")
    plotter.view_xy()
    plotter.show()


def plot_rom(mesh, vmin, vmax, sargs):
    import pyvista as pv
    plotter = pv.Plotter(window_size=(800,600))
    plotter.add_mesh(mesh, scalars='ROM', cmap='plasma', clim=(vmin, vmax), scalar_bar_args=sargs)
    plotter.add_mesh(mesh.contour(), color="black")
    plotter.view_xy()
    plotter.show()


def plot_error_log(mesh, vmin, vmax, sargs):
    import pyvista as pv
    plotter = pv.Plotter(window_size=(800,600))
    plotter.add_mesh(mesh, scalars='Relative Error Log', cmap='inferno', clim=(vmin, vmax), scalar_bar_args=sargs)
    plotter.add_mesh(mesh.contour(), color="black")
    plotter.view_xy()
    plotter.show()


def plot_var(idx, variable, unit, scale=1):
    import pyvista as pv
    import numpy as np

    pv.set_jupyter_backend('static')

    meshfile = '../data/sample_runs/SU2/outputs/fluid.vtk'
    mesh = pv.read(meshfile)

    mesh['Ground-Truth'] = y_test[idx, hfd.indexes[f'{variable}']] * scale
    mesh['ROM'] = prediction[idx, hfd.indexes[f'{variable}']] * scale

    eps = 1e-3
    rel_error = np.abs(mesh['ROM'] - mesh['Ground-Truth']) / (np.abs(mesh['Ground-Truth']) + 1e-12)
    mesh['Relative Error Log'] = np.log10(rel_error + eps)

    vmin_err = mesh['Relative Error Log'].min()
    vmax_err = mesh['Relative Error Log'].max()

    vmin_common = min(mesh['Ground-Truth'].min(), mesh['ROM'].min())
    vmax_common = max(mesh['Ground-Truth'].max(), mesh['ROM'].max())

    sargs_template = dict(
        height=0.1,
        vertical=False,
        position_x=0.25,
        position_y=0.02,
        title_font_size=18,
        label_font_size=14,
        fmt="%.2f",
        n_labels=5,
    )
    sargs_gt = dict(**sargs_template, title=f"{variable} - Ground Truth {unit}")
    sargs_rom = dict(**sargs_template, title=f"{variable} - ROM {unit}")
    sargs_err = dict(**sargs_template, title=f"{variable} - Relative Error log10")

    mesh_gt = mesh.copy()
    mesh_rom = mesh.copy()
    mesh_err = mesh.copy()

    # Agora chama os plots separados, passando mesh, limites e args
    plot_ground_truth(mesh_gt, vmin_common, vmax_common, sargs_gt)
    plot_rom(mesh_rom, vmin_common, vmax_common, sargs_rom)
    plot_error_log(mesh_err, vmin_err, vmax_err, sargs_err)

# %%
plot_var(0, 'Temperature', '[K]')
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>
# <PIL.Image.Image image mode=RGB size=800x600>
# <PIL.Image.Image image mode=RGB size=800x600>

# %%
plot_var(0, 'Pressure', '[MPa]', 1e-6 )
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>
# <PIL.Image.Image image mode=RGB size=800x600>
# <PIL.Image.Image image mode=RGB size=800x600>

# %%
plot_var(0, 'Mach', '', 1 )
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>
# <PIL.Image.Image image mode=RGB size=800x600>
# <PIL.Image.Image image mode=RGB size=800x600>

# %%
# Out:
# Dados carregados do CSV (primeiras 5 linhas):
#    epoch        loss     val_loss
# 0      0  898.453796  1111.829590
# 1      1  896.617432  1109.777832
# 2      2  894.824829  1107.747314
# 3      3  893.022888  1105.683472
# 4      4  891.173584  1103.562134
#
# Colunas disponíveis: ['epoch', 'loss', 'val_loss']
